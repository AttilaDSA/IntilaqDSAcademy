# %% [markdown]
# # Correction Lab Word Embedding n°3

# %%
import LangueFr as FR # LangueFr est le Lab n°2
from tqdm import tqdm
import random,os

# %% [markdown]
# ### Charger les Textes ( Tirés du livre "Candide" de Voltaire)

# %%
chapitres_name_list = [f[:-4] for f in os.listdir('Livres\\Candide\\') if f.endswith('.txt')]
chapitres_list = [open("Livres\\Candide\\"+f+'.txt','r',encoding='utf_8').read() for f in chapitres_name_list]

# %% [markdown]
# ### Transformer le Texte en une liste de Phrase

# %%
stop_chars = ['.',';','?','!']

# %%
def ChapToList(chapitre):
    phrases = []
    i = 0
    for k,c in enumerate(chapitre):
        if c in stop_chars:
            phrases.append(chapitre[i:k])
            i = k+1
    return phrases

# %% [markdown]
# ### Transformer les phrases en listes de mot

# %%
def PhraseToList(phrase):
    phrlist = [
        [''.join([c for c in word if c.isalpha() or c in ["'","-"]]) for word in sentence.split(' ')] for sentence in phrase
    ]
    phrlist = [[word.lower() for word in words if word != ''] for words in phrlist]
    return phrlist

# %%
phrases = []
for chapitre in chapitres_list:
    phrases.extend(PhraseToList(ChapToList(chapitre)))
print(len(phrases))
# Out:
# 2146

# %% [markdown]
# ## Charger le dictionnaire

# %%
import json

# %%
dictionnaire = js = json.load(open('dictionnary.json','r'))

# %%
dictionnaire[0]
# Out:
# {'M': {'mot': 'a', 'no': '1'},
#  'CONT': 'tracer N',
#  'DOM': {'nom': 'écriture, écrits'},
#  'OP': 'lett',
#  'SENS': 'alphabet latin',
#  'OP1': 'R3a1',
#  'CA': {'categorie': 'N', 'type': 'non-anime', 'genre': 'M'}}

# %%
# Format du dictionnaire
element = """
{
    'M':{"mot":%%,...}, # Le mot
    'CONT':?,
    'DOM':{'nom':%%},   # Domaine, Sujet, ...
    'OP':?,
    'SENS':%%,          # Sens du mot
    'OP1':?,
    'CA':{
        'categorie':%%, # Categorie : Nom, Verbe, Préposition, ...
        'type':%%,      # Type : Humain, nom-animé, ...
        'genre':%%,     # Genre : Masculin, Feminin
    }
}
"""

# %% [markdown]
# ### Catégories des mots

# %%
categories = set([v['CA']['categorie'] for v in js])
categories
# Out:
# {'A', 'Adv', 'Conj', 'Interj', 'N', 'Vi', 'Vp', 'Vt'}

# %%
# A : ?
# Adv : Adverbe
# Conj : ?
# Interj : Interjection
# N : Nom
# Vi : Verbe intransitif
# Vt : Verbe Transitif
# Vp : Verbe ?

# %% [markdown]
# ### Vectoriser les mots selon le modèle du Lab n°2

# %% [markdown]
# #### Modéliser les noms

# %%
def strtog(g):
    if g == 'F':
        return FR.FEMININ
    elif g == 'M':
        return FR.MASCULIN
    return FR.SS_GENRE

# %%
# Liste de tous les mots
mots = [
    w['M']['mot'] for w in dictionnaire
]
# Liste de tous les verbes
all_verbes = [
    v for v in js if v['CA']['categorie'] in ['Vp','Vi','Vt']
    if not ' ' in v['M']['mot']
]
# Liste de tous les verbes du 1er groupe (Certain verbe ne sont pas vraiment du 1er groupe comme le verbe aller)
verbes_1er = [
    v['M']['mot'] for v in all_verbes 
    if v['M']['mot'].endswith('er') 
]

# Liste de tous les noms
Noms = [
    v for v in js if v['CA']['categorie'] == 'N'
]
# Dictionnaire des noms modélisés
Noms_modelise = {}

for nom in Noms:
    
    try:
        # Les noms qui finissent par "s" ou "x" ne s'accordent pas au pluriel
        # Les noms qui finissent par "al" s'accordent au pluriel en "aux" et au feminin en "alle" ( à part quelques exceptions)
        # Les règles sont nombreuses (feminin de nombreux :) ) ...
        
        if not nom['M']['mot'].endswith('s') and not nom['M']['mot'].endswith('x'):
            pluriel=FR.accord_s
        else:
            pluriel=None
        
        if not nom['M']['mot'].endswith('al'):
            pluriel=FR.accord_al
        
        # Modéliser 
        Noms_mods[nom['M']['mot']] = FR.mot(
            nom['M']['mot'],genre=strtog(nom['CA']['genre']),accord_pluriel=pluriel
        )
        
    except Exception as exc:
        pass

# %%
Noms_mods
# Out:
# {'a': a,
#  'à-côté': à-côté,
#  'à-coup': à-coup,
#  'à-haut': à-haut,
#  'a-module': a-module,
#  'à-peu-près': à-peu-près,
#  'à-pic': à-pic,
#  'à-plat': à-plat,
#  'à-propos': à-propos,
#  'à-valoir': à-valoir,
#  'à-venir': à-venir,
#  'aa': aa,
#  'aabam': aabam,
#  'aalénien': aalénien,
#  'abaca': abaca,
#  'abacule': abacule,
#  'abaisse': abaisse,
#  'abaisse-langue': abaisse-langue,
#  'abaisse-paupière': abaisse-paupière,
#  'abaissement': abaissement,
#  'abaisseur': abaisseur,
#  'abajoue': abajoue,
#  'abalé': abalé,
#  'abalourdissement': abalourdissement,
#  'abandon': abandon,
#  'abandonnement': abandonnement,
#  'abandonnisme': abandonnisme,
#  'abaque': abaque,
#  'abarco': abarco,
#  'abasie': abasie,
#  'abasourdissement': abasourdissement,
#  'abat-carrage': abat-carrage,
#  'abat-carre': abat-carre,
#  'abat-feuille': abat-feuille,
#  'abat-feuilles': abat-feuilles,
#  'abat-foin': abat-foin,
#  'abat-jour': abat-jour,
#  'abat-son': abat-son,
#  'abat-sons': abat-sons,
#  'abat-vent': abat-vent,
#  'abat-voix': abat-voix,
#  'abatage': abatage,
#  'abatant': abatant,
#  'abâtardissement': abâtardissement,
#  'abatis': abatis,
#  'abats': abats,
#  'abattage': abattage,
#  'abattant': abattant,
#  'abattée': abattée,
#  'abattement': abattement,
#  'abatteuse': abatteuse,
#  'abattis': abattis,
#  'abattoir': abattoir,
#  'abattu': abattu,
#  'abattue': abattue,
#  'abattures': abattures,
#  'abax': abax,
#  'abaza': abaza,
#  'abba': abba,
#  'abbacomite': abbacomite,
#  'abbatiale': abbatiale,
#  'abbaye': abbaye,
#  'abbé': abbé,
#  'abbesse': abbesse,
#  'abbevillien': abbevillien,
#  'abcès': abcès,
#  'abdication': abdication,
#  'abdomen': abdomen,
#  'abdominaux': abdominaux,
#  'abducens': abducens,
#  'abducteur': abducteur,
#  'abduction': abduction,
#  'abécédaire': abécédaire,
#  'abée': abée,
#  'abeille': abeille,
#  'abélie': abélie,
#  'abélisation': abélisation,
#  'aber': aber,
#  'aberdeen-angus': aberdeen-angus,
#  'aberrance': aberrance,
#  'aberration': aberration,
#  'abessif': abessif,
#  'abêtissement': abêtissement,
#  'abich': abich,
#  'abies': abies,
#  'abiétacée': abiétacée,
#  'abiétate': abiétate,
#  'abiétinée': abiétinée,
#  'abîme': abîme,
#  'abiogenèse': abiogenèse,
#  'abiose': abiose,
#  'abjection': abjection,
#  'abjuration': abjuration,
#  'abkhaze': abkhaze,
#  'ablactation': ablactation,
#  'ablaque': ablaque,
#  'ablatif': ablatif,
#  'ablation': ablation,
#  'ablaut': ablaut,
#  'able': able,
#  'ablégat': ablégat,
#  'ablégation': ablégation,
#  'ablépharie': ablépharie,
#  'ableret': ableret,
#  'ablette': ablette,
#  'ablier': ablier,
#  'abloc': abloc,
#  'ablocage': ablocage,
#  'ablot': ablot,
#  'ablutiomanie': ablutiomanie,
#  'ablution': ablution,
#  'ablutions': ablutions,
#  'abm': abm,
#  'abnégation': abnégation,
#  'abobra': abobra,
#  'aboi': aboi,
#  'aboiement': aboiement,
#  'abolition': abolition,
#  'abolitionnisme': abolitionnisme,
#  'abomasite': abomasite,
#  'abomasum': abomasum,
#  'abomination': abomination,
#  'abondance': abondance,
#  'abondement': abondement,
#  'abonnement': abonnement,
#  'abonnissement': abonnissement,
#  'abord': abord,
#  'abordage': abordage,
#  'abordeur': abordeur,
#  'abords': abords,
#  'aborigénat': aborigénat,
#  'abornement': abornement,
#  'abot': abot,
#  'aboteau': aboteau,
#  'abouchement': abouchement,
#  'aboulie': aboulie,
#  'abouna': abouna,
#  'about': about,
#  'aboutage': aboutage,
#  'aboutement': aboutement,
#  'aboutissants': aboutissants,
#  'aboutissement': aboutissement,
#  'aboutoir': aboutoir,
#  'aboutoire': aboutoire,
#  'aboyeur': aboyeur,
#  'abra': abra,
#  'abras': abras,
#  'abrasax': abrasax,
#  'abrasif': abrasif,
#  'abrasimètre': abrasimètre,
#  'abrasimétrie': abrasimétrie,
#  'abrasin': abrasin,
#  'abrasion': abrasion,
#  'abrasivité': abrasivité,
#  'abraxas': abraxas,
#  'abre': abre,
#  'abréaction': abréaction,
#  'abrégé': abrégé,
#  'abrègement': abrègement,
#  'abreuvage': abreuvage,
#  'abreuvement': abreuvement,
#  'abreuvoir': abreuvoir,
#  'abréviation': abréviation,
#  'abri': abri,
#  'abri-sous-roche': abri-sous-roche,
#  'abribus': abribus,
#  'abricot': abricot,
#  'abricotier': abricotier,
#  'abrivent': abrivent,
#  'abrogation': abrogation,
#  'abroma': abroma,
#  'abronia': abronia,
#  'abrotone': abrotone,
#  'abroutissement': abroutissement,
#  'abrupt': abrupt,
#  'abruption': abruption,
#  'abrus': abrus,
#  'abrutissement': abrutissement,
#  'abruzzain': abruzzain,
#  'abruzzais': abruzzais,
#  'abs': abs,
#  'abscisse': abscisse,
#  'abscissine': abscissine,
#  'abscission': abscission,
#  'absence': absence,
#  'absentéisme': absentéisme,
#  'abside': abside,
#  'absidia': absidia,
#  'absidiole': absidiole,
#  'absinthe': absinthe,
#  'absinthisme': absinthisme,
#  'absolu': absolu,
#  'absoluité': absoluité,
#  'absolution': absolution,
#  'absolutisme': absolutisme,
#  'absorbance': absorbance,
#  'absorbeur': absorbeur,
#  'absorptance': absorptance,
#  'absorptant': absorptant,
#  'absorptiomètre': absorptiomètre,
#  'absorptiométrie': absorptiométrie,
#  'absorption': absorption,
#  'absorptivité': absorptivité,
#  'absoute': absoute,
#  'abstention': abstention,
#  'abstentionnisme': abstentionnisme,
#  'abstersion': abstersion,
#  'abstinence': abstinence,
#  'abstract': abstract,
#  'abstraction': abstraction,
#  'abstractionnisme': abstractionnisme,
#  'absurdité': absurdité,
#  'abura': abura,
#  'abus': abus,
#  'abusseau': abusseau,
#  'abusus': abusus,
#  'abysses': abysses,
#  'abyssin': abyssin,
#  'acacia': acacia,
#  'académie': académie,
#  'académification': académification,
#  'académisation': académisation,
#  'académisme': académisme,
#  'acadien': acadien,
#  'acaena': acaena,
#  'acagnardise': acagnardise,
#  'acajou': acajou,
#  'acalcaire': acalcaire,
#  'acalculie': acalculie,
#  'acalèphe': acalèphe,
#  'acalla': acalla,
#  'acalles': acalles,
#  'acalypha': acalypha,
#  'acalyptère': acalyptère,
#  'acanthacée': acanthacée,
#  'acanthaire': acanthaire,
#  'acanthaster': acanthaster,
#  'acanthe': acanthe,
#  'acanthephyra': acanthephyra,
#  'acanthéphyre': acanthéphyre,
#  'acanthisittidé': acanthisittidé,
#  'acanthite': acanthite,
#  'acanthiza': acanthiza,
#  'acanthobdelle': acanthobdelle,
#  'acanthocéphale': acanthocéphale,
#  'acanthocéras': acanthocéras,
#  'acanthochiton': acanthochiton,
#  'acanthocine': acanthocine,
#  'acanthocyte': acanthocyte,
#  'acanthocytose': acanthocytose,
#  'acanthodactyle': acanthodactyle,
#  'acanthode': acanthode,
#  'acanthodien': acanthodien,
#  'acanthoglosse': acanthoglosse,
#  'acantholabre': acantholabre,
#  'acantholyse': acantholyse,
#  'acanthome': acanthome,
#  'acanthopanax': acanthopanax,
#  'acanthoptère': acanthoptère,
#  'acanthoptérygien': acanthoptérygien,
#  'acanthor': acanthor,
#  'acanthose': acanthose,
#  'acanthostaurus': acanthostaurus,
#  'acanthozoïde': acanthozoïde,
#  'acanthuridé': acanthuridé,
#  'acapnie': acapnie,
#  'acardine': acardine,
#  'acardite': acardite,
#  'acariâtreté': acariâtreté,
#  'acaridé': acaridé,
#  'acarien': acarien,
#  'acariose': acariose,
#  'acarocécidie': acarocécidie,
#  'acarus': acarus,
#  'acatalasémie': acatalasémie,
#  'acatalepsie': acatalepsie,
#  'acathésie': acathésie,
#  'acathexis': acathexis,
#  'acathiste': acathiste,
#  'acaulinose': acaulinose,
#  'acauliose': acauliose,
#  'acavacé': acavacé,
#  'accablement': accablement,
#  'accalmie': accalmie,
#  'accaparement': accaparement,
#  'accastillage': accastillage,
#  'accelerando': accelerando,
#  'accélérateur': accélérateur,
#  'accélération': accélération,
#  'accéléré': accéléré,
#  'accélérocompteur': accélérocompteur,
#  'accélérographe': accélérographe,
#  'accéléromètre': accéléromètre,
#  'accélérométrie': accélérométrie,
#  'accense': accense,
#  'accensement': accensement,
#  'accent': accent,
#  'accenteur': accenteur,
#  'accentologie': accentologie,
#  'accentuation': accentuation,
#  'acceptabilité': acceptabilité,
#  'acceptation': acceptation,
#  'accepteur': accepteur,
#  'acception': acception,
#  'accès': accès,
#  'accessibilité': accessibilité,
#  'accessit': accessit,
#  'accessoire': accessoire,
#  'accessoirisation': accessoirisation,
#  'acciaccatura': acciaccatura,
#  'accident': accident,
#  'accidentologie': accidentologie,
#  'accipiens': accipiens,
#  'accipitridé': accipitridé,
#  'accipitriforme': accipitriforme,
#  'accise': accise,
#  'accisien': accisien,
#  'acclamation': acclamation,
#  'acclimatation': acclimatation,
#  'acclimatement': acclimatement,
#  'accointance': accointance,
#  'accoisement': accoisement,
#  'accolade': accolade,
#  'accolage': accolage,
#  'accolement': accolement,
#  'accommodat': accommodat,
#  'accommodation': accommodation,
#  'accommodement': accommodement,
#  'accompagnage': accompagnage,
#  'accompagnement': accompagnement,
#  'accomplissement': accomplissement,
#  'accon': accon,
#  'acconage': acconage,
#  'acconnage': acconnage,
#  'accorage': accorage,
#  'accord': accord,
#  'accord-cadre': accord-cadre,
#  'accordage': accordage,
#  'accordailles': accordailles,
#  'accordance': accordance,
#  'accordée': accordée,
#  'accordement': accordement,
#  'accordéon': accordéon,
#  'accordoir': accordoir,
#  'accore': accore,
#  'accostage': accostage,
#  'accot': accot,
#  'accotar': accotar,
#  'accotement': accotement,
#  'accotoir': accotoir,
#  'accouchée': accouchée,
#  'accouchement': accouchement,
#  'accoucheur': accoucheur,
#  'accoudement': accoudement,
#  'accoudoir': accoudoir,
#  'accouplage': accouplage,
#  'accouple': accouple,
#  'accouplement': accouplement,
#  'accourcissement': accourcissement,
#  'accoutrement': accoutrement,
#  'accoutumance': accoutumance,
#  'accouvage': accouvage,
#  'accra': accra,
#  'accréditation': accréditation,
#  'accréditement': accréditement,
#  'accréditif': accréditif,
#  'accrescence': accrescence,
#  'accrétion': accrétion,
#  'accroc': accroc,
#  'accrochage': accrochage,
#  'accroche': accroche,
#  'accroche-casseroles': accroche-casseroles,
#  'accroche-coeur': accroche-coeur,
#  'accroche-couvercles': accroche-couvercles,
#  'accroche-plat': accroche-plat,
#  'accroche-plats': accroche-plats,
#  'accroche-poissons': accroche-poissons,
#  'accroche-tasses': accroche-tasses,
#  'accrochement': accrochement,
#  'accroissement': accroissement,
#  'accroupissement': accroupissement,
#  'accru': accru,
#  'accrue': accrue,
#  'accu': accu,
#  'accueil': accueil,
#  'accul': accul,
#  'acculée': acculée,
#  'acculement': acculement,
#  'acculturation': acculturation,
#  'accumulateur': accumulateur,
#  'accumulation': accumulation,
#  'accusateur': accusateur,
#  'accusatif': accusatif,
#  'accusation': accusation,
#  'ace': ace,
#  'acéfylline-pipérazine': acéfylline-pipérazine,
#  'acémète': acémète,
#  'acénaphtène': acénaphtène,
#  'acène': acène,
#  'acense': acense,
#  'acensement': acensement,
#  'acéphale': acéphale,
#  'acéphalie': acéphalie,
#  'acéracée': acéracée,
#  'acéras': acéras,
#  'aceratherium': aceratherium,
#  'acerbité': acerbité,
#  'acerdèse': acerdèse,
#  'acerentomon': acerentomon,
#  'acériculture': acériculture,
#  'acérine': acérine,
#  'acervule': acervule,
#  'acervulus': acervulus,
#  'acescence': acescence,
#  'acetabularia': acetabularia,
#  'acétabule': acétabule,
#  'acétabuloplastie': acétabuloplastie,
#  'acetabulum': acetabulum,
#  'acétal': acétal,
#  'acétaldéhyde': acétaldéhyde,
#  'acétalisation': acétalisation,
#  'acétamide': acétamide,
#  'acétanilide': acétanilide,
#  'acétate': acétate,
#  'acétificateur': acétificateur,
#  'acétification': acétification,
#  'acétimètre': acétimètre,
#  'acétimétrie': acétimétrie,
#  'acétoacétanilide': acétoacétanilide,
#  'acétobacter': acétobacter,
#  'acétobutyrate': acétobutyrate,
#  'acétocellulose': acétocellulose,
#  'acétoïne': acétoïne,
#  'acétokinase': acétokinase,
#  'acétol': acétol,
#  'acétolyse': acétolyse,
#  'acétomètre': acétomètre,
#  'acétométrie': acétométrie,
#  'acétone': acétone,
#  'acétone-dicarboxylate': acétone-dicarboxylate,
#  'acétonémie': acétonémie,
#  'acétonide': acétonide,
#  'acétonitrile': acétonitrile,
#  'acétonurie': acétonurie,
#  'acétonylacétone': acétonylacétone,
#  'acétophénone': acétophénone,
#  'acétopropionate': acétopropionate,
#  'acétylacétanilide': acétylacétanilide,
#  'acétylacétate': acétylacétate,
#  'acétylacétone': acétylacétone,
#  'acétylase': acétylase,
#  'acétylation': acétylation,
#  'acétylbenzène': acétylbenzène,
#  'acétylcellulose': acétylcellulose,
#  'acétylcholine': acétylcholine,
#  'acétylcholinestérase': acétylcholinestérase,
#  'acétylcoenzyme': acétylcoenzyme,
#  'acétyldigitoxine': acétyldigitoxine,
#  'acétyle': acétyle,
#  'acétylène': acétylène,
#  'acétylthiokinase': acétylthiokinase,
#  'acétyltransférase': acétyltransférase,
#  'acétylure': acétylure,
#  'achaine': achaine,
#  'achalandage': achalandage,
#  'achalasie': achalasie,
#  'achards': achards,
#  'acharisme': acharisme,
#  'acharnement': acharnement,
#  'achat': achat,
#  'achatinellidé': achatinellidé,
#  'achatinidé': achatinidé,
#  'ache': ache,
#  'acheb': acheb,
#  'acheilie': acheilie,
#  'achélie': achélie,
#  'acheminement': acheminement,
#  'achène': achène,
#  'acherontia': acherontia,
#  'achète': achète,
#  'acheuléen': acheuléen,
#  'achevé': achevé,
#  'achèvement': achèvement,
#  'achigan': achigan,
#  'achille': achille,
#  'achillée': achillée,
#  'achimène': achimène,
#  'acholie': acholie,
#  'acholurie': acholurie,
#  'achondrite': achondrite,
#  'achondroplasie': achondroplasie,
#  'achoppement': achoppement,
#  'achorion': achorion,
#  'achoug': achoug,
#  'achoura': achoura,
#  'achrafi': achrafi,
#  'achras': achras,
#  'achroïde': achroïde,
#  'achroïte': achroïte,
#  'achromat': achromat,
#  'achromaticité': achromaticité,
#  'achromatisation': achromatisation,
#  'achromatisme': achromatisme,
#  'achromatopsie': achromatopsie,
#  'achromie': achromie,
#  'achylie': achylie,
#  'acicule': acicule,
#  'acid-rock': acid-rock,
#  'acidalie': acidalie,
#  'acidanthera': acidanthera,
#  'acide': acide,
#  'acide-alcool': acide-alcool,
#  'acide-aldéhyde': acide-aldéhyde,
#  'acide-cétone': acide-cétone,
#  'acide-partie': acide-partie,
#  'acide-phénol': acide-phénol,
#  'acidémie': acidémie,
#  'acidifiant': acidifiant,
#  'acidification': acidification,
#  'acidimètre': acidimètre,
#  'acidimétrie': acidimétrie,
#  'acidiphilie': acidiphilie,
#  'acidité': acidité,
#  'acidités': acidités,
#  'acido-alcalimétrie': acido-alcalimétrie,
#  'acido-alcalinité': acido-alcalinité,
#  'acido-résistance': acido-résistance,
#  'acido-résistant': acido-résistant,
#  'acidocétose': acidocétose,
#  'acidolyse': acidolyse,
#  'acidophilie': acidophilie,
#  'acidose': acidose,
#  'acidulation': acidulation,
#  'acier': acier,
#  'aciérage': aciérage,
#  'aciération': aciération,
#  'aciérie': aciérie,
#  'aciérisation': aciérisation,
#  'acilius': acilius,
#  'acinace': acinace,
#  'acinèse': acinèse,
#  'acinésie': acinésie,
#  'acineta': acineta,
#  'acinétien': acinétien,
#  'acinétobacter': acinétobacter,
#  'acinitroalcane': acinitroalcane,
#  'acinus': acinus,
#  'acipenséridé': acipenséridé,
#  'acisperme': acisperme,
#  'acmé': acmé,
#  'acméidé': acméidé,
#  'acméisme': acméisme,
#  'acmite': acmite,
#  'acné': acné,
#  'acochlidiidé': acochlidiidé,
#  'acoele': acoele,
#  'acoelomate': acoelomate,
#  'acolytat': acolytat,
#  'acolyte': acolyte,
#  'acompte': acompte,
#  'acon': acon,
#  'aconage': aconage,
#  'aconine': aconine,
#  'aconit': aconit,
#  'aconitine': aconitine,
#  'aconnage': aconnage,
#  'aconnier': aconnier,
#  'acoquinement': acoquinement,
#  'acore': acore,
#  'acorie': acorie,
#  'acouchi': acouchi,
#  'acoumètre': acoumètre,
#  'acoumétrie': acoumétrie,
#  'acouphène': acouphène,
#  'acousmatique': acousmatique,
#  'acousmie': acousmie,
#  'acoustique': acoustique,
#  'acqua-tofana': acqua-tofana,
#  'acquereau': acquereau,
#  'acquêt': acquêt,
#  'acquette': acquette,
#  'acquiescement': acquiescement,
#  'acquis': acquis,
#  'acquisition': acquisition,
#  'acquit-à-caution': acquit-à-caution,
#  'acquittement': acquittement,
#  'acra': acra,
#  'acrama': acrama,
#  'acranien': acranien,
#  'acrasié': acrasié,
#  'acrat': acrat,
#  'acre': acre,
#  'âcreté': âcreté,
#  'acrididé': acrididé,
#  'acridien': acridien,
#  'acridine': acridine,
#  'acridinium': acridinium,
#  'acriflavine': acriflavine,
#  'acrilan': acrilan,
#  'acrimonie': acrimonie,
#  'acrinie': acrinie,
#  'acris': acris,
#  'acrite': acrite,
#  'acroasphyxie': acroasphyxie,
#  'acrobate': acrobate,
#  'acrobatie': acrobatie,
#  'acrobustite': acrobustite,
#  'acrobystite': acrobystite,
#  'acrocéphalie': acrocéphalie,
#  'acrochordidé': acrochordidé,
#  'acrocine': acrocine,
#  'acroclinie': acroclinie,
#  'acrocomia': acrocomia,
#  'acrocyanose': acrocyanose,
#  'acrodermatite': acrodermatite,
#  'acrodontie': acrodontie,
#  'acrodynie': acrodynie,
#  'acroïde': acroïde,
#  'acrokératose': acrokératose,
#  'acrolecte': acrolecte,
#  'acroléine': acroléine,
#  'acrolithe': acrolithe,
#  'acromégalie': acromégalie,
#  'acromélalgie': acromélalgie,
#  'acromion': acromion,
#  'acromyodé': acromyodé,
#  'acron': acron,
#  'acronycte': acronycte,
#  'acronyme': acronyme,
#  'acronymie': acronymie,
#  'acroparesthésie': acroparesthésie,
#  'acropathie': acropathie,
#  'acrophase': acrophase,
#  'acrophobie': acrophobie,
#  'acrophonie': acrophonie,
#  'acropode': acropode,
#  'acropole': acropole,
#  'acropolyarthrite': acropolyarthrite,
#  'acropore': acropore,
#  'acrosome': acrosome,
#  'acrosport': acrosport,
#  'acrostiche': acrostiche,
#  'acrostichum': acrostichum,
#  'acrotère': acrotère,
#  'acrothoracique': acrothoracique,
#  'acryl-ester': acryl-ester,
#  'acrylate': acrylate,
#  'acrylonitrile': acrylonitrile,
#  'acta': acta,
#  'actant': actant,
#  'acte': acte,
#  'actée': actée,
#  'actéon': actéon,
#  'actéonine': actéonine,
#  'actes': actes,
#  'acth': acth,
#  'actias': actias,
#  'actif': actif,
#  'actine': actine,
#  'actinédide': actinédide,
#  'actinelium': actinelium,
#  'acting-out': acting-out,
#  'actiniaire': actiniaire,
#  'actinide': actinide,
#  'actinidia': actinidia,
#  'actinie': actinie,
#  'actinisation': actinisation,
#  'actinisme': actinisme,
#  'actinite': actinite,
#  'actinium': actinium,
#  'actino-réticulose': actino-réticulose,
#  'actino-uranium': actino-uranium,
#  'actinobacillose': actinobacillose,
#  'actinobacillus': actinobacillus,
#  'actinocéphalidé': actinocéphalidé,
#  'actinocéras': actinocéras,
#  'actinocongestine': actinocongestine,
#  'actinodermatose': actinodermatose,
#  'actinodermite': actinodermite,
#  'actinodon': actinodon,
#  'actinolite': actinolite,
#  'actinologie': actinologie,
#  'actinomètre': actinomètre,
#  'actinométrie': actinométrie,
#  'actinomorphie': actinomorphie,
#  'actinomycétale': actinomycétale,
#  'actinomycète': actinomycète,
#  'actinomycine': actinomycine,
#  'actinomycose': actinomycose,
#  'actinon': actinon,
#  'actinophryidien': actinophryidien,
#  'actinophrys': actinophrys,
#  'actinopode': actinopode,
#  'actinoptérygien': actinoptérygien,
#  'actinoscopie': actinoscopie,
#  'actinosphaerium': actinosphaerium,
#  'actinote': actinote,
#  'actinothérapie': actinothérapie,
#  'actinotriche': actinotriche,
#  'actinotroque': actinotroque,
#  'actinule': actinule,
#  'action': action,
#  'actionnalisme': actionnalisme,
#  'actionnariat': actionnariat,
#  'actionnement': actionnement,
#  'actionneur': actionneur,
#  'activant': activant,
#  'activateur': activateur,
#  'activation': activation,
#  'active': active,
#  'activeur': activeur,
#  'activimètre': activimètre,
#  'activimétrie': activimétrie,
#  'activisme': activisme,
#  'activité': activité,
#  'actogramme': actogramme,
#  'actographe': actographe,
#  'actographie': actographie,
#  'actomyosine': actomyosine,
#  'actuaire': actuaire,
#  'actualisateur': actualisateur,
#  'actualisation': actualisation,
#  'actualisme': actualisme,
#  'actualité': actualité,
#  'actualités': actualités,
#  'actuariat': actuariat,
#  'actuateur': actuateur,
#  'actuation': actuation,
#  'acuité': acuité,
#  'acul': acul,
#  'aculéate': aculéate,
#  'acuponcture': acuponcture,
#  'acupuncture': acupuncture,
#  'acutance': acutance,
#  'acyanopsie': acyanopsie,
#  'acyl-carrier-protein': acyl-carrier-protein,
#  'acylation': acylation,
#  'acyle': acyle,
#  'acylium': acylium,
#  'acyloïne': acyloïne,
#  'ada': ada,
#  'adac': adac,
#  'adacna': adacna,
#  'adage': adage,
#  'adagietto': adagietto,
#  'adagio': adagio,
#  'adamantane': adamantane,
#  'adamantoblaste': adamantoblaste,
#  'adamisme': adamisme,
#  'adamite': adamite,
#  'adamsia': adamsia,
#  'adansonia': adansonia,
#  'adapis': adapis,
#  'adaptabilité': adaptabilité,
#  'adaptateur': adaptateur,
#  'adaptation': adaptation,
#  'adaptomètre': adaptomètre,
#  'adaptométrie': adaptométrie,
#  'adatais': adatais,
#  'adatis': adatis,
#  'adav': adav,
#  'adavou': adavou,
#  'addax': addax,
#  'addenda': addenda,
#  'addiction': addiction,
#  'additif': additif,
#  'addition': addition,
#  'additionneur': additionneur,
#  'additionneuse': additionneuse,
#  'additivité': additivité,
#  'adduct': adduct,
#  'adducteur': adducteur,
#  'adduction': adduction,
#  'adduit': adduit,
#  'adelantado': adelantado,
#  'adèle': adèle,
#  'adelge': adelge,
#  'adélite': adélite,
#  'adélomycète': adélomycète,
#  'adelphie': adelphie,
#  'adelphophage': adelphophage,
#  'adelphophagie': adelphophagie,
#  'adénalgie': adénalgie,
#  'adenandra': adenandra,
#  'adenanthera': adenanthera,
#  'adénase': adénase,
#  'adénectomie': adénectomie,
#  'adénine': adénine,
#  'adénite': adénite,
#  'adéno-acanthome': adéno-acanthome,
#  'adénocancer': adénocancer,
#  'adénocarcinome': adénocarcinome,
#  'adénocarpe': adénocarpe,
#  'adénofibrome': adénofibrome,
#  'adénogramme': adénogramme,
#  'adénographie': adénographie,
#  'adénohypophyse': adénohypophyse,
#  'adénoïdectomie': adénoïdectomie,
#  'adénoïdite': adénoïdite,
#  'adénolymphite': adénolymphite,
#  'adénolymphocèle': adénolymphocèle,
#  'adénomatose': adénomatose,
#  'adénome': adénome,
#  'adénomectomie': adénomectomie,
#  'adénomyome': adénomyome,
#  'adénopathie': adénopathie,
#  'adénophlegmon': adénophlegmon,
#  'adénosarcome': adénosarcome,
#  'adénosine': adénosine,
#  'adénosine-triphosphatase': adénosine-triphosphatase,
#  'adénosine-triphosphate': adénosine-triphosphate,
#  'adénostyle': adénostyle,
#  'adénovirose': adénovirose,
#  'adénovirus': adénovirus,
#  'adent': adent,
#  'adénylcyclase': adénylcyclase,
#  'adéphage': adéphage,
#  'adéquation': adéquation,
#  'adermine': adermine,
#  'aderne': aderne,
#  'adessif': adessif,
#  'adhatoda': adhatoda,
#  'adhérence': adhérence,
#  'adhéromètre': adhéromètre,
#  'adhérométrie': adhérométrie,
#  'adhésif': adhésif,
#  'adhésion': adhésion,
#  'adhésivité': adhésivité,
#  'adiabate': adiabate,
#  'adiabatisme': adiabatisme,
#  'adiadococinésie': adiadococinésie,
#  'adiante': adiante,
#  'adiantum': adiantum,
#  'adiaphorèse': adiaphorèse,
#  'adieu': adieu,
#  'adipate': adipate,
#  'adipocyte': adipocyte,
#  'adipolyse': adipolyse,
#  'adiponitrile': adiponitrile,
#  'adipopexie': adipopexie,
#  'adipose': adipose,
#  'adiposité': adiposité,
#  'adipoxanthose': adipoxanthose,
#  'adipsie': adipsie,
#  'adjacence': adjacence,
#  'adjectif': adjectif,
#  'adjectivateur': adjectivateur,
#  'adjectivation': adjectivation,
#  'adjectivisateur': adjectivisateur,
#  'adjectivisation': adjectivisation,
#  'adjoint': adjoint,
#  'adjonction': adjonction,
#  'adjudant': adjudant,
#  'adjudant-chef': adjudant-chef,
#  'adjudant-commandant': adjudant-commandant,
#  'adjudant-major': adjudant-major,
#  'adjudication': adjudication,
#  'adjuration': adjuration,
#  'adjuvant': adjuvant,
#  'adjuvat': adjuvat,
#  'adminicule': adminicule,
#  'administration': administration,
#  'admiration': admiration,
#  'admissibilité': admissibilité,
#  'admittance': admittance,
#  'admixtion': admixtion,
#  'admonestation': admonestation,
#  'admonition': admonition,
#  'adn': adn,
#  'ado': ado,
#  'adobe': adobe,
#  'adolescence': adolescence,
#  'adolescent': adolescent,
#  'adonies': adonies,
#  'adonis': adonis,
#  'adoptianisme': adoptianisme,
#  'adoption': adoption,
#  'adorant': adorant,
#  'adoratio': adoratio,
#  'adoration': adoration,
#  'ados': ados,
#  'adossement': adossement,
#  'adoubement': adoubement,
#  'adouci': adouci,
#  'adoucissage': adoucissage,
#  'adoucissant': adoucissant,
#  'adoucissement': adoucissement,
#  'adoucisseur': adoucisseur,
#  'adoxa': adoxa,
#  'adoxus': adoxus,
#  'adoxylon': adoxylon,
#  'adrar': adrar,
#  'adraste': adraste,
#  'adrastée': adrastée,
#  'adrénaline': adrénaline,
#  'adrénalinémie': adrénalinémie,
#  'adressage': adressage,
#  'adresse': adresse,
#  'adret': adret,
#  'adriamycine': adriamycine,
#  'adrogation': adrogation,
#  'adsl': adsl,
#  'adsorbabilité': adsorbabilité,
#  'adsorbant': adsorbant,
#  'adsorption': adsorption,
#  'adstrat': adstrat,
#  'adulaire': adulaire,
#  'adulation': adulation,
#  'adultération': adultération,
#  'adultère': adultère,
#  'adultisme': adultisme,
#  'advection': advection,
#  'adverbe': adverbe,
#  'adverbialisateur': adverbialisateur,
#  'adverbialisation': adverbialisation,
#  'adversité': adversité,
#  'adygué': adygué,
#  'adynamie': adynamie,
#  'adyton': adyton,
#  'aechmea': aechmea,
#  'aède': aède,
#  'aedeagus': aedeagus,
#  'aegagre': aegagre,
#  'aegagropile': aegagropile,
#  'aegilops': aegilops,
#  'aegipan': aegipan,
#  'aegithale': aegithale,
#  'aegla': aegla,
#  'aegle': aegle,
#  'aegocéras': aegocéras,
#  'aegocère': aegocère,
#  'aegopodium': aegopodium,
#  'aegosome': aegosome,
#  'aegothèle': aegothèle,
#  'aegyrine': aegyrine,
#  'aegyrite': aegyrite,
#  'aelie': aelie,
#  'aélopithèque': aélopithèque,
#  'aelosome': aelosome,
#  'aenigmatite': aenigmatite,
#  'aeolidia': aeolidia,
#  'aeolidiidé': aeolidiidé,
#  'aeolis': aeolis,
#  'aepus': aepus,
#  'aepyornis': aepyornis,
#  'aérage': aérage,
#  'aérateur': aérateur,
#  'aération': aération,
#  'aéraulique': aéraulique,
#  'aérenchyme': aérenchyme,
#  'aérium': aérium,
#  'aéro-club': aéro-club,
#  'aérobic': aérobic,
#  'aérobie': aérobie,
#  'aérobiologie': aérobiologie,
#  'aérobiose': aérobiose,
#  'aérocèle': aérocèle,
#  'aérocheminement': aérocheminement,
#  'aéroclasseur': aéroclasseur,
#  'aérocolie': aérocolie,
#  'aérocondenseur': aérocondenseur,
#  'aérocontaminant': aérocontaminant,
#  'aérocyste': aérocyste,
#  'aérodistorsion': aérodistorsion,
#  'aérodrome': aérodrome,
#  'aérodynamique': aérodynamique,
#  'aérodynamisme': aérodynamisme,
#  'aérodyne': aérodyne,
#  'aéroélasticité': aéroélasticité,
#  'aéroélectronique': aéroélectronique,
#  'aéroembolisme': aéroembolisme,
#  'aéroengrangeur': aéroengrangeur,
#  'aérofaneur': aérofaneur,
#  'aéroflottation': aéroflottation,
#  'aérofrein': aérofrein,
#  'aérofrigorifère': aérofrigorifère,
#  'aérogare': aérogare,
#  'aérogastrie': aérogastrie,
#  'aérogel': aérogel,
#  'aérogénérateur': aérogénérateur,
#  'aéroglisseur': aéroglisseur,
#  'aéroglissière': aéroglissière,
#  'aérogramme': aérogramme,
#  'aérographe': aérographe,
#  'aérolite': aérolite,
#  'aérolithe': aérolithe,
#  'aérologie': aérologie,
#  'aéromancie': aéromancie,
#  'aéromobilité': aéromobilité,
#  'aéromodèle': aéromodèle,
#  'aéromodélisme': aéromodélisme,
#  'aéromonas': aéromonas,
#  'aéromoteur': aéromoteur,
#  'aéronautique': aéronautique,
#  'aéronavale': aéronavale,
#  'aéronef': aéronef,
#  'aéronomie': aéronomie,
#  'aéropathie': aéropathie,
#  'aérophagie': aérophagie,
#  'aérophilatélie': aérophilatélie,
#  ...}

# %% [markdown]
# #### Modéliser les verbes

# %%
verbes = {}

for v in verbes_1er:
    verbes[v]={
        'conjugaison':FR.conjugaison_1er,
        # On pourra après ajouter les verbes du 2ème groupe puis, après beaucoup de travail, les verbes du 3ème
    }

# %% [markdown]
# # Pre-Traitement des Phrases du texte avant Training du Modèle

# %%
mots_associe = {}

# %%
personnes = [FR.JE,FR.TU,FR.IL,FR.NOUS,FR.VOUS,FR.ILS]
genres = [FR.MASCULIN,FR.FEMININ]

# Cette fonction retourne toutes les conjugaisons possibles pour un verbe donné
def formes_conjugaison(verbe):
    # Si on ne connait pas le mode de conjugaison du verbe : return []
    if verbes[verbe]['conjugaison'] is None:
        return []
    
    # Sinon on retourne la liste de toutes les conjugaisons du verbe à toutes les personnes avec tous les genres
    c = []
    for personne in personnes:
        c.append(repr(verbes[verbe]['conjugaison'](Labn2.mot(verbe),personne,genre,Labn2.PRESENT)))
    for personne in personnes:
        for genre in genres:
            c.append(repr(verbes[verbe]['conjugaison'](Labn2.mot(verbe),personne,genre,Labn2.PASSE_COMPOSE)))
      
    return c

# %%
# Afin d'éviter que notre modèle considère les deux mots "douce" et "douces" comme deux mots différents ou bien le verbe 
# "tomber" et sa conjugaison "tombons" comme deux mots différents, cette associe toute conjugaison à son verbe à l'infinitif
# et tous nom au pluriel au même nom au singulier

def AssocierMots(mot):
    
    try:
        # Si le mot a déjà été associé à un autre mot, il n'est pas nécessaire de refaire le traitement
        return mots_associe[mot]
    except:
        pass
    
    if len(mot) <= 3:
        return mot 
    
    if mot in verbes:
        return mot
    
    if mot in mots:
        return mot
    
    # Si le mot se termine par un "s" et qu'il n'est pas contenu dans notre dictionnaire, il y'a de fortes chance qu'en supprimant
    # le "s" on le trouve.
    if mot.endswith('s'):
        if mot[:-1] in mots:
            related[mot] = mot[:-1]
            return mot[:-1]
    # Si le mot se termine par un "e" et qu'il n'est pas contenu dans notre dictionnaire, il y'a de fortes chance qu'en supprimant
    # le "e" on le trouve.
    elif mot.endswith('e'):
        if mot[:-1] in mots:
            related[mot] = mot[:-1]
            return mot[:-1]
    
    # On cherche parmis toutes les conjugaisons possibles de tout les verbes commençant par la même lettre que le mot en question
    for v in [verbe for verbe in verbes if verbe.startswith(mot[0])]:
        if mot in formes_conjugaison(v):
            related[mot] = v
            return mot
    
    # Si rien n'a été trouvé on retourne lmot comme il est
    return mot

# %%
# Cette fonction condense le texte en remplaçant tout les mots par leur associés dans le dictionnaire en utilisant la
# fonction ci-dessus
def CondenserPhrase(phrase):
    phrase_condensee = []
    for w in phrase:
        try:
            phrase_condensee.append(AssocierMots(w))
        except Exception as exc:
            phrase_condensee.append(w)
    return phrase_condensee

# %%
phrases_condensees = []
with tqdm(total=len(phrases)) as pbar:
    for phrase in phrases:
        phrases_condensees.append(CondenserPhrase(phrase))
        pbar.update(1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2146/2146 [01:39<00:00, 21.51it/s]

# %% [markdown]
# # Training des Modèles de Word Embedding

# %%
from gensim.models import Word2Vec
model_1 = Word2Vec(sentences=reconned_sentences, size=300, window=5, min_count=5, workers=4, sg=1)

# %%
model_1.wv.most_similar("baron")
# Out:
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('château', 0.999718427658081),
#  ('vestphalie', 0.9997139573097229),
#  ('philosophe', 0.9997073411941528),
#  ('thunder-ten-tronckh', 0.9996963143348694),
#  ("l'abbé", 0.9996957182884216),
#  ('coup', 0.9996906518936157),
#  ('derrière', 0.9996898770332336),
#  ('gouverneur', 0.9996894598007202),
#  ('maîtresse', 0.9996844530105591),
#  ('temps', 0.9996843338012695)]

# %%
from gensim.models import FastText
model_2 = FastText(sentences=reconned_sentences, size=100, window=5, min_count=5, workers=4, sg=1)

# %%
model_2.wv.most_similar("baron")
# Out:
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('baronne', 0.9999240636825562),
#  ('patron', 0.9998845458030701),
#  ('thunder-ten-tronckh', 0.9998728036880493),
#  ('gouverneur', 0.9998670816421509),
#  ('environ', 0.9998663663864136),
#  ('jésuite', 0.9998574256896973),
#  ('monseigneur', 0.9998557567596436),
#  ('monsieur', 0.999854564666748),
#  ('condition', 0.9998505711555481),
#  ('capitaine', 0.9998494386672974)]

# %% [markdown]
# # Ecriture du poème

# %%
dict1 = model_1.wv
dict2 = model_2.wv

# %%
# Cette fonction utilise les deux modèles dict1 et dict2 afin de construire une phrase à partir d'un mot (complement)
# La phrase est de la forme (Sujet Verbe Complement)
def GenererPhrase(complement):
    
    # Prendre tout les mots similaire à (complement) selon dict 1
    plus_proches = [w[0] for w in dict1.wv.most_similar(complement)]
    
    reccurs = 0;Limit = 5
    verbespp = []
    nomspp = []
    
    with tqdm(total=Limit) as pbar:
        
        while reccurs < Limit:
            
            # Selectionner les verbes parmis les mots similaires
            verbespp.extend([v for v in plus_proches if v in verbes])
            # Selectionner les noms parmis les mots similaires
            nomspp.extend([v for v in plus_proches if v in Noms_mods and not v in verbes and len(v) < 12 and len(v) > 5])
            
            reccurs += 1
            
            # Continuer récursivment à chercher parmis les mots proches
            temp = []
            for p in plus_proches:
                try:
                    temp.extend([w[0] for w in dict1.most_similar(p)])
                except:
                    temp.extend([w[0] for w in dict2.most_similar(p)])    
            plus_proches = temp
            
            # Si on trouve 5 verbes et 5 noms similaires à complement, on s'arrete de chercher
            if len(verbespp) > 5 and len(nomspp) > 5:
                break
                
            pbar.update(1)
    
    
    verbespp = list(set(verbespp))
    nomspp = list(set(nomspp))
    article = [FR.Un,FR.Deux]
    
    i = random.randint(0,len(verbespp)-1);verbespp=verbespp[i] # Choisir un verbe au hasard
    i = random.randint(0,len(nomspp)-1);nomspp=nomspp[i] # Choisir un nom au hasard
    i = random.randint(0,len(article)-1);article1=article[i] # Choisir un article au hasard (Pour construire le Sujet: article + nom)
    i = random.randint(0,len(article)-1);article2=article[i] # Choisir un article au hasard (Pour l'associer au complement: article + nom)
    
    return article1,nomspp,verbespp,article2,

# %%
Titre = 'portugal'
poeme = []

# Choisir un mot au hasrd parmi les mots similaires au titre
# De ce premier mot on va tirer la rime
rimes = [mot_[0] for mot_ in dict2.most_similar(Titre) if len(mot_[0]) < 10]
random.shuffle(rimes)
rime = rimes[0]

rimes = []
frimes = []
limit_poeme = 5 # Le poème est limité à 5 lignes

# Boucle de construction du poème
while len(poeme) < limit_poeme:

    try:
        # générer une phrase à partir du dernier mot (rime)
        nouvelle_ligne = list(GenererPhrase(rime))+[rime]
        poeme.append(nouvelle_ligne)
        
        rimes.append(rime)
        
    except Exception as exc:
        frimes.append(rime) # Frime contient les rime qui ont généré des erreurs (mots similaires non trouvé, ...)

    # Lister les condidats pour la prochaine rime
    nrime = [
        nms for nms in Noms_mods # Selectionner parmi tout les noms modélisé
        if not nms in rimes and  # Les mots qui n'ont pas encore été utilisé comme rime
        not nms in frimes and    # Qui n'ont pas générés d'erreur auparavant
        not nms in verbes and    # On cherche des nom pas des verbes
        nms.endswith(rime[-2:])  # Qui se terminent de la même manière que la rime actuelle
    ]

    try:
        # Selectionner une rime au hasard
        rime = nrime[random.randint(0,len(nrime)-1)]
    except:
        # Si la liste nrime est vide, on choisit de manière aléatoire la nouvelle rime (réinitialisation)
        primes = [rmes[0] for rmes in dict2.most_similar(Titre) if len(rmes[0]) < 10]
        random.shuffle(primes)
        rime = primes[0]
# Out:
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#
#  20%|████████████████▊                                                                   | 1/5 [00:00<00:00, 21.33it/s]
#  40%|█████████████████████████████████▌                                                  | 2/5 [00:00<00:00, 13.38it/s]
#  40%|█████████████████████████████████▌                                                  | 2/5 [00:00<00:00, 11.11it/s]
#  40%|█████████████████████████████████▌                                                  | 2/5 [00:00<00:00, 11.32it/s]
#  40%|█████████████████████████████████▌                                                  | 2/5 [00:00<00:00, 11.77it/s]

# %% [markdown]
# ## Bien conjuguer et accorder le poème

# %%
poeme
# Out:
# [[un, 'habitant', 'dîner', deux, 'ensuite'],
#  [un, 'voyant', 'manger', deux, 'droite'],
#  [un, 'raison', 'officier', un, 'reste'],
#  [un, 'anglais', 'officier', un, 'pirate'],
#  [deux, 'milieu', 'aller', un, 'ponte']]

# %%
# Mettre en bonne forme le poème
for line in poeme:
    try:
        nline = FR.Affirmation_Complementaire(
            FR.Nom_Commun(line[0],Noms_mods[line[1]]),
            FR.mot(line[2],conjugaison=verbes[line[2]]['conjugaison']),
            FR.Nom_Commun(line[3],Noms_mods[line[4]])
        )
        print(nline)
    except Exception as exc:
        pass
print()
# Out:
# un voyant mange deux droites
# une raison officie un reste
# un anglais officie un pirate
# deux milieus allent une ponte

# %% [markdown]
# # FIN
